# %% [markdown]
# # Notebook for cleaning `PROVIDER TABLE`

# %%
import pandas as pd
import numpy as np
 
from sqlalchemy import create_engine,text
user = 'root'
passwords = '7003890541'
host = 'localhost'
port = 3306
database = 'synthea'

engine = create_engine(f"mysql+pymysql://{user}:{passwords}@{host}:{port}/{database}")
def sql(query , engine = engine):
    return pd.read_sql(query,engine)


def select(table_name):
    return sql(f'select * from {table_name} limit 5')


def run(query):
    with engine.connect() as con:
        con.execute(text(query))
        con.commit()

# %%
select('providers')
# Out:
#                                      Id                          ORGANIZATION  \
# 0  3421aa75-dec7-378d-a9e0-0bc764e4cb0d  ef58ea08-d883-3957-8300-150554edc8fb
# 1  c9b3c857-2e24-320c-a79a-87b8a60de63c  69176529-fd1f-3b3f-abce-a0a3626769eb
# 2  0359f968-d1a6-30eb-b1cc-e6cc0b4d3513  5e765f2b-e908-3888-9fc7-df2cb87beb58
# 3  446d1609-858f-3a54-8a52-0c4eacedd00e  f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4
# 4  e6283e46-fd81-3611-9459-0edb1c3da357  e002090d-4e92-300e-b41e-7d1f21dee4c6
#
#                      NAME GENDER        SPECIALITY                  ADDRESS  \
# 0       Tomas436 Sauer652      M  GENERAL PRACTICE         60 HOSPITAL ROAD
# 1   Suzette512 Monahan736      F  GENERAL PRACTICE  330 MOUNT AUBURN STREET
# 2   Gaynell126 Streich926      F  GENERAL PRACTICE          211 PARK STREET
# 3  Patricia625 Salgado989      F  GENERAL PRACTICE       ONE GENERAL STREET
# 4  Jeanmarie510 Beatty507      F  GENERAL PRACTICE    1493 CAMBRIDGE STREET
#
# ...

# %%
query = '''
    alter table providers
    drop column name,
    drop column address,
    drop column zip,
    drop column lat,
    drop column lon;
'''
run(query)

# %%
query = '''
    select column_name from information_schema.columns
    where table_name = 'providers' and
    table_schema = database();
'''
sql(query)
providers_columns = [c[0] for c in sql(query).values.tolist()]

# %%
for col in providers_columns:
    query = f'''
        alter table providers
        rename column {col} to {col.lower()}
    '''
    run(query)

# %%
query = '''
    select column_name from information_schema.columns
    where table_name = 'providers' and
    table_schema = database();
'''
sql(query)
providers_columns = [c[0] for c in sql(query).values.tolist()]

# %%
for col in providers_columns:
    query = f'''
        update providers
        set {col} = lower({col})
    '''
    run(query)

# %%
select('providers')
# Out:
#                                      id                          organization  \
# 0  3421aa75-dec7-378d-a9e0-0bc764e4cb0d  ef58ea08-d883-3957-8300-150554edc8fb
# 1  c9b3c857-2e24-320c-a79a-87b8a60de63c  69176529-fd1f-3b3f-abce-a0a3626769eb
# 2  0359f968-d1a6-30eb-b1cc-e6cc0b4d3513  5e765f2b-e908-3888-9fc7-df2cb87beb58
# 3  446d1609-858f-3a54-8a52-0c4eacedd00e  f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4
# 4  e6283e46-fd81-3611-9459-0edb1c3da357  e002090d-4e92-300e-b41e-7d1f21dee4c6
#
#   gender        speciality        city state  utilization
# 0      m  general practice  leominster    ma         1557
# 1      f  general practice   cambridge    ma         2296
# 2      f  general practice   attleboro    ma         2287
# 3      f  general practice    lawrence    ma         1327
# 4      f  general practice   cambridge    ma         3199
